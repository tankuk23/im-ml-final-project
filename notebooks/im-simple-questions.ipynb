# %% [markdown]
# # Simple Questions

# %% [markdown]
# ## Does the colour of the team make any difference to win chances?
# Hypothesis: No, there should be no difference depending on which colour is assigned

# %%
# !pip install nodejs

# %%
# !pip install plotly_express
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/d4/d6/8a2906f51e073a4be80cab35cfa10e7a34853e60f3ed5304ac470852a08d/plotly_express-0.4.1-py2.py3-none-any.whl
# ...
#      |████████████████████████████████| 11.5MB 8.1MB/s eta 0:00:01    |██████████████████████▎         | 8.0MB 8.1MB/s eta 0:00:01
# ...
#   Found existing installation: plotly 4.0.0
#     Uninstalling plotly-4.0.0:
#       Successfully uninstalled plotly-4.0.0
# ...

# %%
import pandas as pd
import plotly.express as px

# %%
cf = pd.read_csv("../data/colourless_challenger.csv")
mf = pd.read_csv("../data/colourless_master.csv")
gmf = pd.read_csv("../data/colourless_grandmaster.csv")

# %%
print(cf.shape)
print(mf.shape)
print(gmf.shape)
# Out:
# (26904, 52)
# (107125, 52)
# (65896, 52)

# %%
px.bar(cf, y="winnerColour")
# Out:
# <div>
#
#
#             <div id="36948263-f306-4d05-88fa-e5a51c479f4b" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("36948263-f306-4d05-88fa-e5a51c479f4b")) {
#                     Plotly.newPlot(
#                         '36948263-f306-4d05-88fa-e5a51c479f4b',
# ...

# %%
# wins
# Out:
# <div>
#
#
#             <div id="f11736ce-2298-472d-94e7-62297446d5bb" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f11736ce-2298-472d-94e7-62297446d5bb")) {
#                     Plotly.newPlot(
#                         'f11736ce-2298-472d-94e7-62297446d5bb',
# ...
